-- %%
CREATE CATALOG IF NOT EXISTS claim_investigation_analysis;

-- %%
-- 1. Create the Landing layer inside your custom catalog
CREATE SCHEMA IF NOT EXISTS claim_investigation_analysis.00_landing;

-- 2. Create the Bronze layer
CREATE SCHEMA IF NOT EXISTS claim_investigation_analysis.01_bronze;

-- 3. Create the Silver layer
CREATE SCHEMA IF NOT EXISTS claim_investigation_analysis.02_silver;

-- 4. Create the Gold layer
CREATE SCHEMA IF NOT EXISTS claim_investigation_analysis.03_gold;

-- %%
DROP SCHEMA IF EXISTS workspace.claim_investigation_analysis_00_landing CASCADE;
DROP SCHEMA IF EXISTS workspace.claim_investigation_analysis_01_bronze CASCADE;
DROP SCHEMA IF EXISTS workspace.claim_investigation_analysis_02_silver CASCADE;
DROP SCHEMA IF EXISTS workspace.claim_investigation_analysis_03_gold CASCADE;
